# %%
import pymongo
import pprint
from IPython.display import clear_output

# %%
client = pymongo.MongoClient('mongodb://analytics-student:analytics-password@cluster0-shard-00-00-jxeqq.mongodb.net:27017,cluster0-shard-00-01-jxeqq.mongodb.net:27017,cluster0-shard-00-02-jxeqq.mongodb.net:27017/?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin')

# %%
trips = client.citibike.trips

# %%
# Replace XXXX with your aggregation pipeline to answer the question:
# Citibike trips that start at station id 279 end most frequently at what station id?
pipeline = [

      {  '$group':{
            '_id':{"endingStationId":"$end station id", 'start station id':'$start station id'},
            'count':{"$sum":1},
            
        }
      },
        {
            '$sort':{'count':-1}
        },

]
clear_output()

# %%
# print the results
clear_output()
for trip in trips.aggregate(pipeline):
    pprint.pprint(trip)
# Out:
# {'_id': {'endingStationId': 519}, 'count': 24361}
# {'_id': {'endingStationId': 435}, 'count': 17392}
# {'_id': {'endingStationId': 293}, 'count': 17055}
# {'_id': {'endingStationId': 497}, 'count': 15723}
# {'_id': {'endingStationId': 477}, 'count': 14370}
# {'_id': {'endingStationId': 285}, 'count': 13834}
# {'_id': {'endingStationId': 402}, 'count': 13258}
# {'_id': {'endingStationId': 490}, 'count': 13007}
# {'_id': {'endingStationId': 284}, 'count': 12656}
# {'_id': {'endingStationId': 459}, 'count': 12606}
# {'_id': {'endingStationId': 368}, 'count': 12042}
# {'_id': {'endingStationId': 168}, 'count': 11963}
# {'_id': {'endingStationId': 492}, 'count': 11917}
# {'_id': {'endingStationId': 151}, 'count': 11795}
# {'_id': {'endingStationId': 379}, 'count': 11697}
# {'_id': {'endingStationId': 426}, 'count': 11632}
# {'_id': {'endingStationId': 521}, 'count': 11541}
# {'_id': {'endingStationId': 444}, 'count': 11488}
# {'_id': {'endingStationId': 523}, 'count': 11463}
# {'_id': {'endingStationId': 537}, 'count': 11296}
# {'_id': {'endingStationId': 250}, 'count': 10985}
# {'_id': {'endingStationId': 358}, 'count': 10745}
# {'_id': {'endingStationId': 359}, 'count': 10695}
# {'_id': {'endingStationId': 504}, 'count': 10512}
# {'_id': {'endingStationId': 442}, 'count': 10317}
# {'_id': {'endingStationId': 446}, 'count': 10135}
# {'_id': {'endingStationId': 472}, 'count': 10087}
# {'_id': {'endingStationId': 116}, 'count': 9929}
# {'_id': {'endingStationId': 382}, 'count': 9847}
# {'_id': {'endingStationId': 494}, 'count': 9732}
# {'_id': {'endingStationId': 127}, 'count': 9660}
# {'_id': {'endingStationId': 505}, 'count': 9573}
# {'_id': {'endingStationId': 327}, 'count': 9552}
# {'_id': {'endingStationId': 462}, 'count': 9475}
# {'_id': {'endingStationId': 3002}, 'count': 9438}
# {'_id': {'endingStationId': 527}, 'count': 9135}
# {'_id': {'endingStationId': 518}, 'count': 9037}
# {'_id': {'endingStationId': 509}, 'count': 9026}
# {'_id': {'endingStationId': 496}, 'count': 8947}
# {'_id': {'endingStationId': 514}, 'count': 8854}
# {'_id': {'endingStationId': 453}, 'count': 8844}
# {'_id': {'endingStationId': 128}, 'count': 8803}
# {'_id': {'endingStationId': 545}, 'count': 8743}
# {'_id': {'endingStationId': 3141}, 'count': 8693}
# {'_id': {'endingStationId': 161}, 'count': 8665}
# {'_id': {'endingStationId': 229}, 'count': 8598}
# {'_id': {'endingStationId': 417}, 'count': 8507}
# {'_id': {'endingStationId': 498}, 'count': 8507}
# {'_id': {'endingStationId': 483}, 'count': 8489}
# {'_id': {'endingStationId': 237}, 'count': 8436}
# {'_id': {'endingStationId': 173}, 'count': 8404}
# {'_id': {'endingStationId': 445}, 'count': 8385}
# {'_id': {'endingStationId': 489}, 'count': 8370}
# {'_id': {'endingStationId': 387}, 'count': 8333}
# {'_id': {'endingStationId': 2006}, 'count': 8277}
# {'_id': {'endingStationId': 147}, 'count': 8215}
# {'_id': {'endingStationId': 536}, 'count': 8214}
# {'_id': {'endingStationId': 466}, 'count': 8182}
# {'_id': {'endingStationId': 380}, 'count': 8181}
# {'_id': {'endingStationId': 486}, 'count': 8132}
# {'_id': {'endingStationId': 461}, 'count': 8104}
# {'_id': {'endingStationId': 479}, 'count': 8087}
# {'_id': {'endingStationId': 474}, 'count': 8069}
# {'_id': {'endingStationId': 488}, 'count': 8013}
# {'_id': {'endingStationId': 236}, 'count': 8006}
# {'_id': {'endingStationId': 432}, 'count': 7996}
# {'_id': {'endingStationId': 439}, 'count': 7954}
# {'_id': {'endingStationId': 503}, 'count': 7866}
# {'_id': {'endingStationId': 465}, 'count': 7855}
# {'_id': {'endingStationId': 335}, 'count': 7779}
# {'_id': {'endingStationId': 334}, 'count': 7732}
# {'_id': {'endingStationId': 484}, 'count': 7724}
# {'_id': {'endingStationId': 463}, 'count': 7635}
# {'_id': {'endingStationId': 297}, 'count': 7611}
# {'_id': {'endingStationId': 482}, 'count': 7606}
# {'_id': {'endingStationId': 487}, 'count': 7605}
# {'_id': {'endingStationId': 517}, 'count': 7511}
# {'_id': {'endingStationId': 507}, 'count': 7471}
# {'_id': {'endingStationId': 499}, 'count': 7458}
# {'_id': {'endingStationId': 428}, 'count': 7457}
# {'_id': {'endingStationId': 2003}, 'count': 7423}
# {'_id': {'endingStationId': 491}, 'count': 7410}
# {'_id': {'endingStationId': 546}, 'count': 7384}
# {'_id': {'endingStationId': 347}, 'count': 7366}
# {'_id': {'endingStationId': 457}, 'count': 7318}
# {'_id': {'endingStationId': 515}, 'count': 7303}
# {'_id': {'endingStationId': 301}, 'count': 7269}
# {'_id': {'endingStationId': 410}, 'count': 7261}
# {'_id': {'endingStationId': 450}, 'count': 7249}
# {'_id': {'endingStationId': 345}, 'count': 7189}
# {'_id': {'endingStationId': 317}, 'count': 7124}
# {'_id': {'endingStationId': 526}, 'count': 7123}
# {'_id': {'endingStationId': 405}, 'count': 7112}
# {'_id': {'endingStationId': 326}, 'count': 7094}
# {'_id': {'endingStationId': 511}, 'count': 7068}
# {'_id': {'endingStationId': 540}, 'count': 7058}
# {'_id': {'endingStationId': 312}, 'count': 7036}
# {'_id': {'endingStationId': 352}, 'count': 7023}
# {'_id': {'endingStationId': 388}, 'count': 6953}
# {'_id': {'endingStationId': 212}, 'count': 6917}
# {'_id': {'endingStationId': 348}, 'count': 6909}
# {'_id': {'endingStationId': 433}, 'count': 6898}
# {'_id': {'endingStationId': 468}, 'count': 6871}
# {'_id': {'endingStationId': 251}, 'count': 6854}
# {'_id': {'endingStationId': 478}, 'count': 6802}
# {'_id': {'endingStationId': 223}, 'count': 6799}
# {'_id': {'endingStationId': 528}, 'count': 6755}
# {'_id': {'endingStationId': 401}, 'count': 6719}
# {'_id': {'endingStationId': 529}, 'count': 6718}
# {'_id': {'endingStationId': 475}, 'count': 6604}
# {'_id': {'endingStationId': 470}, 'count': 6576}
# {'_id': {'endingStationId': 3233}, 'count': 6562}
# {'_id': {'endingStationId': 510}, 'count': 6560}
# {'_id': {'endingStationId': 520}, 'count': 6532}
# {'_id': {'endingStationId': 458}, 'count': 6524}
# {'_id': {'endingStationId': 383}, 'count': 6496}
# {'_id': {'endingStationId': 531}, 'count': 6475}
# {'_id': {'endingStationId': 305}, 'count': 6432}
# {'_id': {'endingStationId': 253}, 'count': 6427}
# {'_id': {'endingStationId': 346}, 'count': 6418}
# {'_id': {'endingStationId': 281}, 'count': 6413}
# {'_id': {'endingStationId': 2021}, 'count': 6399}
# {'_id': {'endingStationId': 307}, 'count': 6391}
# {'_id': {'endingStationId': 167}, 'count': 6380}
# {'_id': {'endingStationId': 329}, 'count': 6349}
# {'_id': {'endingStationId': 438}, 'count': 6346}
# {'_id': {'endingStationId': 300}, 'count': 6278}
# {'_id': {'endingStationId': 447}, 'count': 6259}
# {'_id': {'endingStationId': 263}, 'count': 6224}
# {'_id': {'endingStationId': 434}, 'count': 6189}
# {'_id': {'endingStationId': 153}, 'count': 6097}
# {'_id': {'endingStationId': 336}, 'count': 6033}
# {'_id': {'endingStationId': 375}, 'count': 6030}
# {'_id': {'endingStationId': 500}, 'count': 6024}
# {'_id': {'endingStationId': 476}, 'count': 6020}
# {'_id': {'endingStationId': 174}, 'count': 5966}
# {'_id': {'endingStationId': 3168}, 'count': 5942}
# {'_id': {'endingStationId': 361}, 'count': 5939}
# {'_id': {'endingStationId': 3140}, 'count': 5904}
# {'_id': {'endingStationId': 495}, 'count': 5871}
# {'_id': {'endingStationId': 268}, 'count': 5857}
# {'_id': {'endingStationId': 2012}, 'count': 5712}
# {'_id': {'endingStationId': 394}, 'count': 5681}
# {'_id': {'endingStationId': 265}, 'count': 5668}
# {'_id': {'endingStationId': 448}, 'count': 5659}
# {'_id': {'endingStationId': 3230}, 'count': 5654}
# {'_id': {'endingStationId': 480}, 'count': 5619}
# {'_id': {'endingStationId': 493}, 'count': 5600}
# {'_id': {'endingStationId': 533}, 'count': 5438}
# {'_id': {'endingStationId': 2008}, 'count': 5400}
# {'_id': {'endingStationId': 3167}, 'count': 5376}
# {'_id': {'endingStationId': 252}, 'count': 5350}
# {'_id': {'endingStationId': 485}, 'count': 5295}
# {'_id': {'endingStationId': 3147}, 'count': 5294}
# {'_id': {'endingStationId': 524}, 'count': 5239}
# {'_id': {'endingStationId': 280}, 'count': 5199}
# {'_id': {'endingStationId': 228}, 'count': 5155}
# {'_id': {'endingStationId': 325}, 'count': 5116}
# {'_id': {'endingStationId': 513}, 'count': 5097}
# {'_id': {'endingStationId': 257}, 'count': 5061}
# {'_id': {'endingStationId': 3156}, 'count': 5055}
# {'_id': {'endingStationId': 502}, 'count': 5055}
# {'_id': {'endingStationId': 440}, 'count': 5024}
# {'_id': {'endingStationId': 3224}, 'count': 5016}
# {'_id': {'endingStationId': 303}, 'count': 5016}
# {'_id': {'endingStationId': 415}, 'count': 5011}
# {'_id': {'endingStationId': 501}, 'count': 4921}
# {'_id': {'endingStationId': 363}, 'count': 4902}
# {'_id': {'endingStationId': 304}, 'count': 4894}
# {'_id': {'endingStationId': 522}, 'count': 4891}
# {'_id': {'endingStationId': 455}, 'count': 4861}
# {'_id': {'endingStationId': 72}, 'count': 4795}
# {'_id': {'endingStationId': 3143}, 'count': 4779}
# {'_id': {'endingStationId': 355}, 'count': 4776}
# {'_id': {'endingStationId': 508}, 'count': 4762}
# {'_id': {'endingStationId': 3142}, 'count': 4712}
# {'_id': {'endingStationId': 3145}, 'count': 4699}
# {'_id': {'endingStationId': 195}, 'count': 4668}
# {'_id': {'endingStationId': 441}, 'count': 4636}
# {'_id': {'endingStationId': 328}, 'count': 4604}
# {'_id': {'endingStationId': 2004}, 'count': 4596}
# {'_id': {'endingStationId': 469}, 'count': 4546}
# {'_id': {'endingStationId': 449}, 'count': 4520}
# {'_id': {'endingStationId': 369}, 'count': 4510}
# {'_id': {'endingStationId': 2010}, 'count': 4494}
# {'_id': {'endingStationId': 385}, 'count': 4467}
# {'_id': {'endingStationId': 3158}, 'count': 4435}
# {'_id': {'endingStationId': 357}, 'count': 4434}
# {'_id': {'endingStationId': 3177}, 'count': 4428}
# {'_id': {'endingStationId': 3244}, 'count': 4417}
# {'_id': {'endingStationId': 530}, 'count': 4410}
# {'_id': {'endingStationId': 254}, 'count': 4405}
# {'_id': {'endingStationId': 3093}, 'count': 4389}
# {'_id': {'endingStationId': 296}, 'count': 4362}
# {'_id': {'endingStationId': 238}, 'count': 4356}
# {'_id': {'endingStationId': 3137}, 'count': 4296}
# {'_id': {'endingStationId': 456}, 'count': 4291}
# {'_id': {'endingStationId': 225}, 'count': 4279}
# {'_id': {'endingStationId': 137}, 'count': 4268}
# {'_id': {'endingStationId': 324}, 'count': 4266}
# {'_id': {'endingStationId': 311}, 'count': 4257}
# {'_id': {'endingStationId': 309}, 'count': 4219}
# {'_id': {'endingStationId': 79}, 'count': 4217}
# {'_id': {'endingStationId': 3165}, 'count': 4197}
# {'_id': {'endingStationId': 377}, 'count': 4172}
# {'_id': {'endingStationId': 525}, 'count': 4165}
# {'_id': {'endingStationId': 430}, 'count': 4160}
# {'_id': {'endingStationId': 279}, 'count': 4157}
# {'_id': {'endingStationId': 3223}, 'count': 4156}
# {'_id': {'endingStationId': 267}, 'count': 4148}
# {'_id': {'endingStationId': 295}, 'count': 4146}
# {'_id': {'endingStationId': 412}, 'count': 4112}
# {'_id': {'endingStationId': 146}, 'count': 4095}
# {'_id': {'endingStationId': 164}, 'count': 4095}
# {'_id': {'endingStationId': 3090}, 'count': 4069}
# {'_id': {'endingStationId': 367}, 'count': 4037}
# {'_id': {'endingStationId': 315}, 'count': 4014}
# {'_id': {'endingStationId': 2002}, 'count': 3965}
# {'_id': {'endingStationId': 350}, 'count': 3927}
# {'_id': {'endingStationId': 247}, 'count': 3898}
# {'_id': {'endingStationId': 473}, 'count': 3885}
# {'_id': {'endingStationId': 3159}, 'count': 3818}
# {'_id': {'endingStationId': 3235}, 'count': 3802}
# {'_id': {'endingStationId': 3222}, 'count': 3783}
# {'_id': {'endingStationId': 330}, 'count': 3769}
# {'_id': {'endingStationId': 3164}, 'count': 3758}
# {'_id': {'endingStationId': 150}, 'count': 3736}
# {'_id': {'endingStationId': 320}, 'count': 3724}
# {'_id': {'endingStationId': 3175}, 'count': 3661}
# {'_id': {'endingStationId': 386}, 'count': 3631}
# {'_id': {'endingStationId': 160}, 'count': 3612}
# {'_id': {'endingStationId': 316}, 'count': 3609}
# {'_id': {'endingStationId': 362}, 'count': 3582}
# {'_id': {'endingStationId': 3104}, 'count': 3552}
# {'_id': {'endingStationId': 532}, 'count': 3460}
# {'_id': {'endingStationId': 308}, 'count': 3453}
# {'_id': {'endingStationId': 3132}, 'count': 3438}
# {'_id': {'endingStationId': 3148}, 'count': 3437}
# {'_id': {'endingStationId': 393}, 'count': 3403}
# {'_id': {'endingStationId': 3163}, 'count': 3339}
# {'_id': {'endingStationId': 376}, 'count': 3287}
# {'_id': {'endingStationId': 259}, 'count': 3287}
# {'_id': {'endingStationId': 152}, 'count': 3282}
# {'_id': {'endingStationId': 3155}, 'count': 3278}
# {'_id': {'endingStationId': 306}, 'count': 3275}
# {'_id': {'endingStationId': 351}, 'count': 3275}
# {'_id': {'endingStationId': 302}, 'count': 3269}
# {'_id': {'endingStationId': 2000}, 'count': 3259}
# {'_id': {'endingStationId': 319}, 'count': 3232}
# {'_id': {'endingStationId': 264}, 'count': 3211}
# {'_id': {'endingStationId': 360}, 'count': 3198}
# {'_id': {'endingStationId': 3231}, 'count': 3190}
# {'_id': {'endingStationId': 224}, 'count': 3139}
# {'_id': {'endingStationId': 249}, 'count': 3106}
# {'_id': {'endingStationId': 427}, 'count': 3097}
# {'_id': {'endingStationId': 337}, 'count': 3095}
# {'_id': {'endingStationId': 2009}, 'count': 3066}
# {'_id': {'endingStationId': 323}, 'count': 3035}
# {'_id': {'endingStationId': 310}, 'count': 3014}
# {'_id': {'endingStationId': 356}, 'count': 3012}
# {'_id': {'endingStationId': 342}, 'count': 2991}
# {'_id': {'endingStationId': 276}, 'count': 2990}
# {'_id': {'endingStationId': 2023}, 'count': 2977}
# {'_id': {'endingStationId': 3173}, 'count': 2961}
# {'_id': {'endingStationId': 3160}, 'count': 2925}
# {'_id': {'endingStationId': 454}, 'count': 2877}
# {'_id': {'endingStationId': 340}, 'count': 2811}
# {'_id': {'endingStationId': 422}, 'count': 2786}
# {'_id': {'endingStationId': 260}, 'count': 2784}
# {'_id': {'endingStationId': 3135}, 'count': 2772}
# {'_id': {'endingStationId': 366}, 'count': 2770}
# {'_id': {'endingStationId': 3171}, 'count': 2736}
# {'_id': {'endingStationId': 3170}, 'count': 2703}
# {'_id': {'endingStationId': 157}, 'count': 2696}
# {'_id': {'endingStationId': 467}, 'count': 2696}
# {'_id': {'endingStationId': 460}, 'count': 2693}
# {'_id': {'endingStationId': 2017}, 'count': 2663}
# {'_id': {'endingStationId': 3119}, 'count': 2660}
# {'_id': {'endingStationId': 534}, 'count': 2652}
# {'_id': {'endingStationId': 3150}, 'count': 2650}
# {'_id': {'endingStationId': 539}, 'count': 2621}
# {'_id': {'endingStationId': 3107}, 'count': 2618}
# {'_id': {'endingStationId': 3169}, 'count': 2617}
# {'_id': {'endingStationId': 3112}, 'count': 2616}
# {'_id': {'endingStationId': 3134}, 'count': 2589}
# {'_id': {'endingStationId': 3139}, 'count': 2561}
# {'_id': {'endingStationId': 3176}, 'count': 2534}
# {'_id': {'endingStationId': 217}, 'count': 2504}
# {'_id': {'endingStationId': 411}, 'count': 2495}
# {'_id': {'endingStationId': 516}, 'count': 2482}
# {'_id': {'endingStationId': 3162}, 'count': 2451}
# {'_id': {'endingStationId': 3154}, 'count': 2417}
# {'_id': {'endingStationId': 391}, 'count': 2413}
# {'_id': {'endingStationId': 3136}, 'count': 2384}
# {'_id': {'endingStationId': 403}, 'count': 2378}
# {'_id': {'endingStationId': 341}, 'count': 2361}
# {'_id': {'endingStationId': 291}, 'count': 2340}
# {'_id': {'endingStationId': 3151}, 'count': 2321}
# {'_id': {'endingStationId': 270}, 'count': 2315}
# {'_id': {'endingStationId': 408}, 'count': 2314}
# {'_id': {'endingStationId': 3166}, 'count': 2308}
# {'_id': {'endingStationId': 392}, 'count': 2302}
# {'_id': {'endingStationId': 3092}, 'count': 2283}
# {'_id': {'endingStationId': 3161}, 'count': 2258}
# {'_id': {'endingStationId': 3086}, 'count': 2255}
# {'_id': {'endingStationId': 512}, 'count': 2250}
# {'_id': {'endingStationId': 384}, 'count': 2196}
# {'_id': {'endingStationId': 314}, 'count': 2188}
# {'_id': {'endingStationId': 239}, 'count': 2139}
# {'_id': {'endingStationId': 332}, 'count': 2007}
# {'_id': {'endingStationId': 3108}, 'count': 1998}
# {'_id': {'endingStationId': 3153}, 'count': 1998}
# {'_id': {'endingStationId': 243}, 'count': 1987}
# {'_id': {'endingStationId': 414}, 'count': 1930}
# {'_id': {'endingStationId': 282}, 'count': 1902}
# {'_id': {'endingStationId': 406}, 'count': 1899}
# {'_id': {'endingStationId': 3129}, 'count': 1887}
# {'_id': {'endingStationId': 3124}, 'count': 1868}
# {'_id': {'endingStationId': 3172}, 'count': 1854}
# {'_id': {'endingStationId': 3226}, 'count': 1844}
# {'_id': {'endingStationId': 481}, 'count': 1836}
# {'_id': {'endingStationId': 83}, 'count': 1827}
# {'_id': {'endingStationId': 266}, 'count': 1815}
# {'_id': {'endingStationId': 331}, 'count': 1804}
# {'_id': {'endingStationId': 423}, 'count': 1737}
# {'_id': {'endingStationId': 3087}, 'count': 1733}
# {'_id': {'endingStationId': 82}, 'count': 1732}
# {'_id': {'endingStationId': 437}, 'count': 1721}
# {'_id': {'endingStationId': 2022}, 'count': 1710}
# {'_id': {'endingStationId': 248}, 'count': 1704}
# {'_id': {'endingStationId': 261}, 'count': 1697}
# {'_id': {'endingStationId': 3110}, 'count': 1695}
# {'_id': {'endingStationId': 471}, 'count': 1682}
# {'_id': {'endingStationId': 3242}, 'count': 1672}
# {'_id': {'endingStationId': 3146}, 'count': 1667}
# {'_id': {'endingStationId': 274}, 'count': 1653}
# {'_id': {'endingStationId': 389}, 'count': 1648}
# {'_id': {'endingStationId': 398}, 'count': 1635}
# {'_id': {'endingStationId': 313}, 'count': 1629}
# {'_id': {'endingStationId': 3113}, 'count': 1624}
# {'_id': {'endingStationId': 3236}, 'count': 1583}
# {'_id': {'endingStationId': 143}, 'count': 1542}
# {'_id': {'endingStationId': 3106}, 'count': 1540}
# {'_id': {'endingStationId': 3238}, 'count': 1530}
# {'_id': {'endingStationId': 395}, 'count': 1515}
# {'_id': {'endingStationId': 349}, 'count': 1511}
# {'_id': {'endingStationId': 400}, 'count': 1479}
# {'_id': {'endingStationId': 244}, 'count': 1475}
# {'_id': {'endingStationId': 3074}, 'count': 1467}
# {'_id': {'endingStationId': 390}, 'count': 1463}
# {'_id': {'endingStationId': 322}, 'count': 1436}
# {'_id': {'endingStationId': 3115}, 'count': 1407}
# {'_id': {'endingStationId': 3178}, 'count': 1357}
# {'_id': {'endingStationId': 258}, 'count': 1344}
# {'_id': {'endingStationId': 354}, 'count': 1342}
# {'_id': {'endingStationId': 3078}, 'count': 1308}
# {'_id': {'endingStationId': 3109}, 'count': 1290}
# {'_id': {'endingStationId': 3096}, 'count': 1283}
# {'_id': {'endingStationId': 321}, 'count': 1270}
# {'_id': {'endingStationId': 416}, 'count': 1266}
# {'_id': {'endingStationId': 232}, 'count': 1255}
# {'_id': {'endingStationId': 3097}, 'count': 1252}
# {'_id': {'endingStationId': 242}, 'count': 1238}
# {'_id': {'endingStationId': 396}, 'count': 1223}
# {'_id': {'endingStationId': 241}, 'count': 1217}
# {'_id': {'endingStationId': 339}, 'count': 1215}
# {'_id': {'endingStationId': 3064}, 'count': 1208}
# {'_id': {'endingStationId': 418}, 'count': 1192}
# {'_id': {'endingStationId': 3077}, 'count': 1171}
# {'_id': {'endingStationId': 3082}, 'count': 1170}
# {'_id': {'endingStationId': 3144}, 'count': 1165}
# {'_id': {'endingStationId': 3138}, 'count': 1163}
# {'_id': {'endingStationId': 262}, 'count': 1147}
# {'_id': {'endingStationId': 3118}, 'count': 1136}
# {'_id': {'endingStationId': 3125}, 'count': 1133}
# {'_id': {'endingStationId': 278}, 'count': 1123}
# {'_id': {'endingStationId': 344}, 'count': 1117}
# {'_id': {'endingStationId': 3103}, 'count': 1112}
# {'_id': {'endingStationId': 3101}, 'count': 1107}
# {'_id': {'endingStationId': 353}, 'count': 1088}
# {'_id': {'endingStationId': 3157}, 'count': 1077}
# {'_id': {'endingStationId': 3126}, 'count': 1062}
# {'_id': {'endingStationId': 364}, 'count': 1039}
# {'_id': {'endingStationId': 3085}, 'count': 1039}
# {'_id': {'endingStationId': 419}, 'count': 1039}
# {'_id': {'endingStationId': 120}, 'count': 1023}
# {'_id': {'endingStationId': 3232}, 'count': 1002}
# {'_id': {'endingStationId': 397}, 'count': 1001}
# {'_id': {'endingStationId': 3079}, 'count': 982}
# {'_id': {'endingStationId': 3116}, 'count': 980}
# {'_id': {'endingStationId': 3111}, 'count': 976}
# {'_id': {'endingStationId': 3243}, 'count': 918}
# {'_id': {'endingStationId': 3117}, 'count': 909}
# {'_id': {'endingStationId': 399}, 'count': 903}
# {'_id': {'endingStationId': 343}, 'count': 888}
# {'_id': {'endingStationId': 275}, 'count': 888}
# {'_id': {'endingStationId': 298}, 'count': 883}
# {'_id': {'endingStationId': 421}, 'count': 879}
# {'_id': {'endingStationId': 3102}, 'count': 840}
# {'_id': {'endingStationId': 3088}, 'count': 837}
# {'_id': {'endingStationId': 407}, 'count': 827}
# {'_id': {'endingStationId': 365}, 'count': 815}
# {'_id': {'endingStationId': 3084}, 'count': 811}
# {'_id': {'endingStationId': 3098}, 'count': 796}
# {'_id': {'endingStationId': 420}, 'count': 780}
# {'_id': {'endingStationId': 233}, 'count': 757}
# {'_id': {'endingStationId': 3068}, 'count': 729}
# {'_id': {'endingStationId': 3052}, 'count': 719}
# {'_id': {'endingStationId': 144}, 'count': 716}
# {'_id': {'endingStationId': 3071}, 'count': 707}
# {'_id': {'endingStationId': 373}, 'count': 688}
# {'_id': {'endingStationId': 3081}, 'count': 683}
# {'_id': {'endingStationId': 3083}, 'count': 675}
# {'_id': {'endingStationId': 3067}, 'count': 663}
# {'_id': {'endingStationId': 409}, 'count': 619}
# {'_id': {'endingStationId': 3080}, 'count': 616}
# {'_id': {'endingStationId': 3062}, 'count': 582}
# {'_id': {'endingStationId': 3094}, 'count': 575}
# {'_id': {'endingStationId': 3076}, 'count': 575}
# {'_id': {'endingStationId': 245}, 'count': 570}
# {'_id': {'endingStationId': 3073}, 'count': 568}
# {'_id': {'endingStationId': 3047}, 'count': 564}
# {'_id': {'endingStationId': 3057}, 'count': 562}
# {'_id': {'endingStationId': 2001}, 'count': 560}
# {'_id': {'endingStationId': 436}, 'count': 558}
# {'_id': {'endingStationId': 372}, 'count': 554}
# {'_id': {'endingStationId': 3042}, 'count': 551}
# {'_id': {'endingStationId': 3121}, 'count': 551}
# {'_id': {'endingStationId': 216}, 'count': 549}
# {'_id': {'endingStationId': 3099}, 'count': 522}
# {'_id': {'endingStationId': 3122}, 'count': 520}
# {'_id': {'endingStationId': 3049}, 'count': 520}
# {'_id': {'endingStationId': 3066}, 'count': 512}
# {'_id': {'endingStationId': 3054}, 'count': 512}
# {'_id': {'endingStationId': 3058}, 'count': 508}
# {'_id': {'endingStationId': 3060}, 'count': 485}
# {'_id': {'endingStationId': 3180}, 'count': 478}
# {'_id': {'endingStationId': 3072}, 'count': 476}
# {'_id': {'endingStationId': 3114}, 'count': 470}
# {'_id': {'endingStationId': 3120}, 'count': 467}
# {'_id': {'endingStationId': 3050}, 'count': 459}
# {'_id': {'endingStationId': 289}, 'count': 458}
# {'_id': {'endingStationId': 3069}, 'count': 457}
# {'_id': {'endingStationId': 3241}, 'count': 442}
# {'_id': {'endingStationId': 3221}, 'count': 422}
# {'_id': {'endingStationId': 3055}, 'count': 420}
# {'_id': {'endingStationId': 3105}, 'count': 419}
# {'_id': {'endingStationId': 443}, 'count': 409}
# {'_id': {'endingStationId': 3016}, 'count': 407}
# {'_id': {'endingStationId': 119}, 'count': 407}
# {'_id': {'endingStationId': 3046}, 'count': 406}
# {'_id': {'endingStationId': 3095}, 'count': 401}
# {'_id': {'endingStationId': 3091}, 'count': 400}
# {'_id': {'endingStationId': 3070}, 'count': 397}
# {'_id': {'endingStationId': 3089}, 'count': 377}
# {'_id': {'endingStationId': 3056}, 'count': 365}
# {'_id': {'endingStationId': 3229}, 'count': 347}
# {'_id': {'endingStationId': 3237}, 'count': 332}
# {'_id': {'endingStationId': 3127}, 'count': 300}
# {'_id': {'endingStationId': 3063}, 'count': 297}
# {'_id': {'endingStationId': 3179}, 'count': 273}
# {'_id': {'endingStationId': 3048}, 'count': 253}
# {'_id': {'endingStationId': 3041}, 'count': 244}
# {'_id': {'endingStationId': 3128}, 'count': 235}
# {'_id': {'endingStationId': 3059}, 'count': 234}
# {'_id': {'endingStationId': 3065}, 'count': 227}
# {'_id': {'endingStationId': 3123}, 'count': 220}
# {'_id': {'endingStationId': 3043}, 'count': 220}
# {'_id': {'endingStationId': 3053}, 'count': 206}
# {'_id': {'endingStationId': 3044}, 'count': 176}
# {'_id': {'endingStationId': 3075}, 'count': 160}
# {'_id': {'endingStationId': 3061}, 'count': 156}
# {'_id': {'endingStationId': 3246}, 'count': 139}
# {'_id': {'endingStationId': 2005}, 'count': 109}
# {'_id': {'endingStationId': 3019}, 'count': 99}
# {'_id': {'endingStationId': 3234}, 'count': 93}
# {'_id': {'endingStationId': 3100}, 'count': 77}
# {'_id': {'endingStationId': 255}, 'count': 62}
# {'_id': {'endingStationId': 3017}, 'count': 52}
# {'_id': {'endingStationId': 3219}, 'count': 43}
# {'_id': {'endingStationId': 3240}, 'count': 26}
# {'_id': {'endingStationId': 3186}, 'count': 4}
# {'_id': {'endingStationId': 3214}, 'count': 2}
# {'_id': {'endingStationId': 294}, 'count': 2}
# {'_id': {'endingStationId': 3213}, 'count': 1}
# {'_id': {'endingStationId': 3211}, 'count': 1}
# {'_id': {'endingStationId': 3220}, 'count': 1}
# {'_id': {'endingStationId': 3184}, 'count': 1}
# {'_id': {'endingStationId': 3185}, 'count': 1}
# {'_id': {'endingStationId': 3202}, 'count': 1}
